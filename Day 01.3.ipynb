# %% [markdown]
# # Day 1: Arrays
#
# ## Problem: Next Permutation

# %% [markdown]
# ## Links:
#
# ### LeetCode:
# https://leetcode.com/problems/next-permutation/
#
# ### Coding Ninjas:
# https://www.codingninjas.com/codestudio/problems/893046?topList=striver-sde-sheet-problems&utm_source=striver&utm_medium=website

# %% [markdown]
# ![Day%2001.3.png](attachment:Day%2001.3.png)

# %%
class Solution(object):
    def nextPermutation(self, nums):
        """
        :type nums: List[int]
        :rtype: None Do not return anything, modify nums in-place instead.
        """
        n = len(nums)
        # Start iterating from the end of the given permutation.
        for i in range(n - 2, -1, -1):

            if nums[i] < nums[i + 1]:

                # Decreasing element found.
                # To store the index of just greater element.
                ind = n - 1

                for j in range(i + 1, n):

                    if nums[j] < nums[i]:
                        # Element found.
                        ind = j - 1
                        break

                # Swap the ith and element at index 'id'.
                nums[i], nums[ind] = nums[ind], nums[i]

                # Reverse rest of the elements.
                for j in range(((n - i) // 2)):
                    nums[i + 1 + j], nums[n - 1 - j] = nums[n - 1 - j], nums[i + 1 + j]
                return nums

        # Next greater permuation doesn't exists. So, return the smallest one.
        nums.sort()
            
        return nums
